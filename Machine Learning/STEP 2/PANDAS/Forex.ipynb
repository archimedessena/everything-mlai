# %%
import pandas as pd

# %%
forex = pd.read_csv('data/eurusd_hour.csv')

# %%
forex
# Out:
#              Date   Time       BO       BH       BL       BC      BCh  \
# 0      2005-05-02  00:00  1.28520  1.28520  1.28400  1.28440 -0.00080
# 1      2005-05-02  01:00  1.28440  1.28480  1.28390  1.28420 -0.00020
# 2      2005-05-02  02:00  1.28430  1.28540  1.28410  1.28510  0.00080
# 3      2005-05-02  03:00  1.28510  1.28590  1.28500  1.28510  0.00000
# 4      2005-05-02  04:00  1.28520  1.28590  1.28490  1.28550  0.00030
# ...           ...    ...      ...      ...      ...      ...      ...
# 93079  2020-04-29  18:00  1.08620  1.08851  1.08611  1.08713  0.00093
# 93080  2020-04-29  19:00  1.08711  1.08823  1.08659  1.08748  0.00037
# 93081  2020-04-29  20:00  1.08747  1.08788  1.08691  1.08708 -0.00039
# 93082  2020-04-29  21:00  1.08708  1.08740  1.08699  1.08714  0.00006
# 93083  2020-04-29  22:00  1.08728  1.08760  1.08727  1.08743  0.00015
#
#             AO       AH       AL       AC      ACh
# 0      1.28540  1.28540  1.28420  1.28460 -0.00080
# ...

# %%
forex.describe()
# Out:
#                  BO            BH            BL            BC           BCh  \
# count  93084.000000  93084.000000  93084.000000  93084.000000  9.308400e+04
# mean       1.265734      1.266755      1.264736      1.265733 -8.928495e-07
# std        0.126894      0.127060      0.126722      0.126892  1.544143e-03
# min        1.035530      1.036970      1.033950      1.035550 -2.505000e-02
# 25%        1.139878      1.140728      1.139130      1.139880 -6.000000e-04
# 50%        1.274100      1.275315      1.272955      1.274105  1.000000e-05
# 75%        1.357615      1.358770      1.356532      1.357630  6.000000e-04
# max        1.601310      1.603840      1.599200      1.601390  3.022000e-02
#
#                  AO            AH            AL            AC           ACh
# count  93084.000000  93084.000000  93084.000000  93084.000000  93084.000000
# mean       1.265900      1.266917      1.264897      1.265899     -0.000001
# ...

# %%
forex.tail(10)
# Out:
#              Date   Time       BO       BH       BL       BC      BCh  \
# 93074  2020-04-29  13:00  1.08567  1.08676  1.08542  1.08635  0.00068
# 93075  2020-04-29  14:00  1.08636  1.08660  1.08422  1.08512 -0.00124
# 93076  2020-04-29  15:00  1.08513  1.08574  1.08446  1.08519  0.00006
# 93077  2020-04-29  16:00  1.08520  1.08563  1.08467  1.08471 -0.00049
# 93078  2020-04-29  17:00  1.08470  1.08670  1.08462  1.08625  0.00155
# 93079  2020-04-29  18:00  1.08620  1.08851  1.08611  1.08713  0.00093
# 93080  2020-04-29  19:00  1.08711  1.08823  1.08659  1.08748  0.00037
# 93081  2020-04-29  20:00  1.08747  1.08788  1.08691  1.08708 -0.00039
# 93082  2020-04-29  21:00  1.08708  1.08740  1.08699  1.08714  0.00006
# 93083  2020-04-29  22:00  1.08728  1.08760  1.08727  1.08743  0.00015
#
#             AO       AH       AL       AC      ACh
# 93074  1.08580  1.08689  1.08556  1.08647  0.00067
# 93075  1.08648  1.08674  1.08435  1.08524 -0.00124
# ...

# %%
forex.shape
# Out:
# (93084, 12)

# %%
# Take a look at the date for the first index

# %%
forex.loc[0, 'Date']
# Out:
# '2005-05-02'

# %%
forex.loc[50, 'Date'] # 50th index
# Out:
# '2005-05-04'

# %%
# converting datetime, i.e converting a column to daytime

# %%
forex['Date'] = pd.to_datetime(forex['Date'], format = '%Y-%m-%d %I-%p')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     431             try:
# --> 432                 values, tz = conversion.datetime_to_datetime64(arg)
#     433                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-bab12d13e2ac> in <module>
# ----> 1 forex['Date'] = pd.to_datetime(forex['Date'], format = '%Y-%m-%d %I-%p')
#
# ...
