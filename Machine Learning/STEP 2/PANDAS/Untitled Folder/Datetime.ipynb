# %%
import pandas as pd

# %%
bit = pd.read_csv('bit/bitt.csv')

# %%
bit
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
bit.shape
# Out:
# (23674, 7)

# %%
bit.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
bit['Low'].mean()
# Out:
# 322.25552124693405

# %%
bit.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
bit['Date']
# Out:
# 0        2020-03-13 08-PM
# 1        2020-03-13 07-PM
# 2        2020-03-13 06-PM
# 3        2020-03-13 05-PM
# 4        2020-03-13 04-PM
#                ...
# 23669    2017-07-01 03-PM
# 23670    2017-07-01 02-PM
# 23671    2017-07-01 01-PM
# 23672    2017-07-01 12-PM
# 23673    2017-07-01 11-AM
# Name: Date, Length: 23674, dtype: object

# %%
bit['Open'].max()
# Out:
# 1418.61

# %%
bit['Open'].mean()
# Out:
# 324.93337247613465

# %%
#converting date to a good for format

# %%
#that is datetime format

# %%
#bit['Date'] = pd.to_datetime(bit['Date'], format = '%Y-%m-%d %I-%p')

# %%
#bit['Date']
bit.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
# loading with this code attach can change the date
#d_parser = lambda x:pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
#bit = pd.read_csv('bit/bitt.csv', parse_dates=['Date'], date_parser=d_parser)

# %%
# to apply dayname to each of the series

# %%
bit['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
# creating a new column and allocating it to the day of the week for which the 
#those high and lows happened

# %%
bit['DayOfWeek'] = bit['Date'].dt.day_name()

# %%
bit
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
# How to view the earliest date
bit['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
# most recent

# %%
bit['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
#date subtraction

# %%
bit['Date'].max()-bit['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
#filtering by date

# %%
#Looking for 2020 and above

# %%
b = (bit['Date']>= '2020')
bit.loc[b]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt = (bit['Date'] >='2019') & (bit['Date'] < '2020')

# %%
bit.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
# more filtering

# %%
filts = (bit['Date'] >=pd.to_datetime('2019-01-01')) & (bit['Date']<pd.to_datetime('2020-01-01'))

# %%
bit.loc[filts]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
#setting index to date and make it permanent

# %%
bit.set_index('Date', inplace=True)

# %%
bit
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
# Data for 2019 only

# %%
bit['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
bit['2020']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-03-13 20:00:00     Friday
# ...

# %%
bit['2020']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-03-13 20:00:00     Friday
# ...

# %%
# now slicing

# %%
# Data for January and Feb 2020
bit['2019':'2020-01']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-01-31 23:00:00  ETHUSD  181.73  181.73  179.00  179.74   438575.26
# 2020-01-31 22:00:00  ETHUSD  180.66  182.24  180.03  181.73   754254.39
# 2020-01-31 21:00:00  ETHUSD  180.31  181.04  179.98  180.66   657922.36
# 2020-01-31 20:00:00  ETHUSD  179.19  180.51  179.13  180.31   979846.20
# 2020-01-31 19:00:00  ETHUSD  179.10  179.57  178.71  179.19   353169.87
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2020-01-31 23:00:00    Friday
# ...

# %%
#more slicing
bit['2018-09':'2020-01']
# Out:
#                      Symbol    Open    High     Low   Close     Volume  \
# Date
# 2020-01-31 23:00:00  ETHUSD  181.73  181.73  179.00  179.74  438575.26
# 2020-01-31 22:00:00  ETHUSD  180.66  182.24  180.03  181.73  754254.39
# 2020-01-31 21:00:00  ETHUSD  180.31  181.04  179.98  180.66  657922.36
# 2020-01-31 20:00:00  ETHUSD  179.19  180.51  179.13  180.31  979846.20
# 2020-01-31 19:00:00  ETHUSD  179.10  179.57  178.71  179.19  353169.87
# ...                     ...     ...     ...     ...     ...        ...
# 2018-09-01 04:00:00  ETHUSD  288.59  289.39  285.85  286.41  529804.94
# 2018-09-01 03:00:00  ETHUSD  284.62  289.11  284.61  288.59  868842.79
# 2018-09-01 02:00:00  ETHUSD  283.69  285.00  283.69  284.62  340284.10
# 2018-09-01 01:00:00  ETHUSD  284.40  285.00  283.57  283.69  465186.66
# 2018-09-01 00:00:00  ETHUSD  281.94  284.40  281.94  284.40  579384.68
#
#                     DayOfWeek
# Date
# 2020-01-31 23:00:00    Friday
# 2020-01-31 22:00:00    Friday
# ...

# %%
bit['2019-12':]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-01 00:00:00  ETHUSD  151.78  151.78  150.51  150.78   407029.11
# 2019-11-30 23:00:00  ETHUSD  151.58  152.36  151.58  151.78   317114.79
# 2019-11-30 22:00:00  ETHUSD  152.10  153.55  151.58  151.58   876578.44
# 2019-11-30 21:00:00  ETHUSD  150.99  152.40  150.89  152.10   714971.27
# 2019-11-30 20:00:00  ETHUSD  150.68  151.17  150.24  150.99   252314.15
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2019-12-01 00:00:00    Sunday
# ...

# %%
#to get the average closing value on the above date

# %%
bit['2020-01']['Close'].mean()
# Out:
# 155.08573924731172

# %%
# high
bit['2019']['High'].mean()
# Out:
# 181.7666118721458

# %%
bit['2019']['Low'].min()
# Out:
# 100.15

# %%
bit['2019']['Low'].max()
# Out:
# 348.84

# %%
bit['2019']['Low'].mean()
# Out:
# 179.65662328767232

# %%
#Resampling
# Resampling in order to see the highest value by the day
# for series!
bit['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
#Accessing for a particular day

# %%
highs = bit['Open'].resample('D').max()

# %%
highs['2020-01-04']
# Out:
# 134.55

# %%
# to plot the highs

# %%
# %matplotlib inline

# %%
highs.plot()

# %%
# to resample using multiple columns

# %%
v = bit.resample('W').agg({'Close':'mean', 'High':'max', 'Low':'min', 'Volume':'sum'})

# %%
v.describe()
# Out:
#              Close         High         Low        Volume
# count   142.000000   142.000000  142.000000  1.420000e+02
# mean    324.297444   361.800915  281.388873  3.352764e+08
# std     234.572765   270.898576  189.762648  3.987614e+08
# min      86.737976    94.620000   80.600000  4.436353e+07
# 25%     175.419747   187.860000  153.557500  1.094779e+08
# 50%     231.204732   270.745000  203.690000  2.233384e+08
# 75%     403.012545   457.147500  357.625000  3.792344e+08
# max    1253.946786  1419.960000  951.000000  2.360772e+09

# %%
bit['Close'].mean()
# Out:
# 324.92660133479814

# %%
v.plot()
